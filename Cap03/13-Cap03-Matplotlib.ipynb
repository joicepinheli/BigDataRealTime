# %% [markdown]
# # <font color='blue'>Data Science Academy</font>
# # <font color='blue'>Big Data Real-Time Analytics com Python e Spark</font>
#
# # <font color='blue'>Capítulo 3</font>

# %% [markdown]
# ## Configuração e Customização Avançada do Matplotlib

# %%
# Importando os Pacotes
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import Image
import matplotlib
# %matplotlib inline
mpl.__version__
# Out:
# '3.1.3'

# %%
# Visualizando os Estilos disponíveis no Matplotlib
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
# Criando uma função para criar um Plot
def cria_plot():
    x = np.random.randn(5000, 6)
    (figure, axes) = plt.subplots(figsize = (16,10))
    (n, bins, patches) = axes.hist(x,12,
                                  density = 1,
                                  histtype = 'bar',
                                  label = ['Color1', 'Color2', 'Color3', 'Color4', 'Color5', 'Color6'])
    axes.set_title('Histograma\nPara\nDistribuição Normal', fontsize = 25)
    axes.set_xlabel('Dados', fontsize = 16)
    axes.set_ylabel('Frequência', fontsize = 16)
    axes.legend()
    plt.show()

# %%
# Chamando a Função
cria_plot()

# %%
# Usuários Windows utilizem:
# !dir estilos

# Usuários Mac/Linux utilizem:
# !ls -l estilos
# Out:
#  O volume na unidade C ‚ Acer
#  O N£mero de S‚rie do Volume ‚ 40F4-D6C9
#
#  Pasta de C:\DSA_Scripts\BigDataRealTime\Cap03\estilos
#
# 16/12/2021  21:00    <DIR>          .
# 16/12/2021  21:00    <DIR>          ..
# 16/12/2021  20:55               592 personalestilo-1.mplstyle
# 16/12/2021  20:55               592 personalestilo-2.mplstyle
#                2 arquivo(s)          1.184 bytes
#                2 pasta(s)   399.967.535.104 bytes dispon¡veis

# %%
# Usuários Windows utilizem:
# !type estilos/personalestilo-1.mplstyle

# Usuários Mac/Linux utilizem:
# !cat estilos/personalestilo-1.mplstyle
# Out:
# A sintaxe do comando est  incorreta.

# %%
# Usando um estilo customizado
plt.style.use("estilos/personalestilo-1.mplstyle")

# %%
# Chamando a Função
cria_plot()

# %% [markdown]
# ## Subplots
# Utilizaremos o dataset sobre automóveis do repositório de Machine Learning da UCI: [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.html)
#
# [Automobile Data Set](https://archive.ics.uci.edu/ml/datasets/Automobile)

# %% [markdown]
# ## Usando o Pandas para Carregar os Dados

# %%
# Importando o pacote Sys (gerenciamento do SO)
import sys

# Trazendo o diretório Lib para ser reconhecido pelo Jupyter Notebook
sys.path.append('lib') 

# Módulos que estão dentro do diretório Lib
import geradados, geraplot, radar

# %%
# Chamando uma função do pacote Gera Dados
dados = geradados.get_raw_data()
dados.head()
# Out:
#    riskiness  losses  make fuel type aspiration doors   body drive  \
# 0          2     164  audi       gas        std  four  sedan   fwd
# 1          2     164  audi       gas        std  four  sedan   4wd
# 2          1     158  audi       gas        std  four  sedan   fwd
# 3          1     158  audi       gas      turbo  four  sedan   fwd
# 4          2     192   bmw       gas        std   two  sedan   rwd
#
#   engine location  wheel base  ...  engine size  fuel system  bore  stroke  \
# 0           front        99.8  ...          109         mpfi  3.19     3.4
# 1           front        99.4  ...          136         mpfi  3.19     3.4
# 2           front       105.8  ...          136         mpfi  3.19     3.4
# 3           front       105.8  ...          131         mpfi  3.13     3.4
# 4           front       101.2  ...          108         mpfi  3.50     2.8
#
#   compression ratio horsepower  peak rpm city mpg  highway mpg  price
# 0              10.0        102      5500       24           30  13950
# 1               8.0        115      5500       18           22  17450
# 2               8.5        110      5500       19           25  17710
# 3               8.3        140      5500       17           20  23875
# 4               8.8        101      5800       23           29  16430
#
# [5 rows x 26 columns]

# %%
# Criando um subset
dados_subset = geradados.get_limited_data()
dados_subset.head()
# Out:
#    make  price  city mpg  highway mpg  horsepower  weight  riskiness  losses
# 0  audi  13950        24           30         102    2337          2     164
# 1  audi  17450        18           22         115    2824          2     164
# 2  audi  17710        19           25         110    2844          1     158
# 3  audi  23875        17           20         140    3086          1     158
# 4   bmw  16430        23           29         101    2395          2     192

# %%
# Chamando um método
geradados.get_all_auto_makes()
# Out:
# array(['audi', 'bmw', 'chevrolet', 'dodge', 'honda', 'jaguar', 'mazda',
#        'mercedes-benz', 'mitsubishi', 'nissan', 'peugot', 'plymouth',
#        'porsche', 'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'],
#       dtype=object)

# %%
# Esta função retorna dois parâmetros
(fabricantes, total) = geradados.get_make_counts(dados_subset)
total
# Out:
# [('audi', 4),
#  ('bmw', 4),
#  ('chevrolet', 3),
#  ('dodge', 8),
#  ('honda', 13),
#  ('jaguar', 1),
#  ('mazda', 11),
#  ('mercedes-benz', 5),
#  ('mitsubishi', 10),
#  ('nissan', 18),
#  ('peugot', 7),
#  ('plymouth', 6),
#  ('porsche', 1),
#  ('saab', 6),
#  ('subaru', 12),
#  ('toyota', 31),
#  ('volkswagen', 8),
#  ('volvo', 11)]

# %%
# Pode ser definido o limite de dados que irão retornar (Lower Bownd)
dados = geradados.get_limited_data(lower_bound = 6)
dados.head()
# Out:
#      make  price  city mpg  highway mpg  horsepower  weight  riskiness  losses
# 11  dodge   5572        37           41          68    1876          1     118
# 12  dodge   6377        31           38          68    1876          1     118
# 13  dodge   7957        24           30         102    2128          1     118
# 14  dodge   6229        31           38          68    1967          1     148
# 15  dodge   6692        31           38          68    1989          1     148

# %%
# Quantidade de índices
len(dados.index)
# Out:
# 141

# %% [markdown]
# ## Normalizando os Dados

# %%
# Realizando uma cópia dos dados, e colocando em um novo dataframe
dados_normalizados = dados.copy()

# Renomeando uma colunas
dados_normalizados.rename(columns = {'horsepower':'power'}, inplace = True)

# %%
# Visualizando as primeiras linhas
dados_normalizados.head()
# Out:
#      make  price  city mpg  highway mpg  power  weight  riskiness  losses
# 11  dodge   5572        37           41     68    1876          1     118
# 12  dodge   6377        31           38     68    1876          1     118
# 13  dodge   7957        24           30    102    2128          1     118
# 14  dodge   6229        31           38     68    1967          1     148
# 15  dodge   6692        31           38     68    1989          1     148

# %%
# Valores mais altos para estas variáveis
geradados.norm_columns(['city mpg', 'highway mpg', 'power'], dados_normalizados)
dados_normalizados.head()
# Out:
#      make  price  city mpg  highway mpg     power  weight  riskiness  losses
# 11  dodge   5572   0.62500      0.59375  0.108108    1876          1     118
# 12  dodge   6377   0.43750      0.50000  0.108108    1876          1     118
# 13  dodge   7957   0.21875      0.25000  0.337838    2128          1     118
# 14  dodge   6229   0.43750      0.50000  0.108108    1967          1     148
# 15  dodge   6692   0.43750      0.50000  0.108108    1989          1     148

# %%
# Valores mais baixos para estas variáveis
geradados.invert_norm_columns(['price','weight', 'riskiness', 'losses'], dados_normalizados)
dados_normalizados.head()
# Out:
#      make     price  city mpg  highway mpg     power    weight  riskiness  \
# 11  dodge  0.974068   0.62500      0.59375  0.108108  0.897031        0.4
# 12  dodge  0.928086   0.43750      0.50000  0.108108  0.897031        0.4
# 13  dodge  0.837836   0.21875      0.25000  0.337838  0.737840        0.4
# 14  dodge  0.936540   0.43750      0.50000  0.108108  0.839545        0.4
# 15  dodge  0.910093   0.43750      0.50000  0.108108  0.825648        0.4
#
#       losses
# 11  0.722513
# 12  0.722513
# 13  0.722513
# 14  0.565445
# 15  0.565445

# %% [markdown]
# ## Plots

# %%
# ####
figure = plt.figure(figsize = (15, 5))
prices_gs = mpl.gridspec.GridSpec(1,1)
prices_axes = geraplot.make_autos_price_plot(figure, prices_gs, dados)
plt.show()

# %%
# Preenchendo os valores NaN com zeros
df.fillna(0).describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e5470ddc57ba> in <module>
#       1 # Preenchendo os valores NaN com zeros
# ----> 2 df.fillna(0).describe()
#
# NameError: name 'df' is not defined

# %%
# Criando um histograma, para visualizar a distribuição de frequência da nova variável
df.hist('Min_Por_Km')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-4853b11ec379> in <module>
#       1 # Criando um histograma, para visualizar a distribuição de frequência da nova variável
# ----> 2 df.hist('Min_Por_Km')
#
# NameError: name 'df' is not defined

# %%
# Alterando a quantidade de colunas do histograma
df.hist('Min_Por_Km', bins = 20)

# %%
# Salvando o gráfico
df.hist('Min_Por_Km', bins = 20, figsize = (10,8))
plt.xlim((5, 11))
plt.ylim((0, 12))
plt.title("Histograma Minutos por KM")
plt.grid(False)
plt.savefig('imagens/hist_minutos_por_km.png')

# %%
# Realizando o Plot da variável Distância
df['Distancia'].plot()

# %%
# Retornando as 15 primeiras linhas do DataFrame
df.head(15)

# %%
# Calculando a média de distância em uma janela (window) de 2 horas
df['Distancia'].plot()
pd.Series(df['Distancia']).rolling(window = 2).mean().plot()

# %%
# Calculando a soma de distância em uma janela (window) de 2 horas
df['Distancia'].plot()
pd.Series(df['Distancia']).rolling(window = 2).sum().plot()

# %%
# Usando Indexação
df.index

# %%
# Realizando o filtro de Indexação utilizando as datas
df['2015-11':'2015-12']

# %%
# Realizando um plot usando a indexação e o nome de uma coluna
df['2015-11':'2016-1-1']['Distancia'].plot()

# %%
# Realizando a localização dos dados a partir de um índice
df.loc['2015-8-12']

# %%
# Salvando o resultado intermediário em um arquivo csv
df.to_csv('data/dataframe_saved_v1.csv')

# %%
# Realizando o reset do índice
df.reset_index()

# %% [markdown]
# # Fim
